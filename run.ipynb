# %%
# %run gui.py

# %%
# %run G-UI.py

# %%
# %run problem.py
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# File ~\Documents\NULL CLASS project\Translation_app\problem.py:26
#      23 input_sequence = np.array([[start_token]])
#      25 # Predict the next word probabilities
# ---> 26 prediction = model.predict(input_sequence)
#      27 predicted_word_index = np.argmax(prediction[0])
#      29 # Get the predicted word based on the index
#
# File ~\anaconda2\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...
